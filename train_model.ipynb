# %%
import pandas as pd
import numpy as np
import seaborn as sns
from imblearn.over_sampling import SMOTE
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
import joblib

import warnings
warnings.filterwarnings("ignore")

# %%
data_model=pd.read_excel("Processed_data.xlsx")

# %%
data_model=pd.DataFrame(data_model,columns=data_model.columns)
#data_model.isnull().sum()

# %%
data_model.head()
# Out:
#         Age  EducationBackground  EmpDepartment  DistanceFromHome  \
# 0  0.333333                  0.6            1.0          0.321429
# 1  0.690476                  0.6            1.0          0.464286
# 2  0.523810                  1.0            1.0          0.142857
# 3  0.547619                  0.0            0.4          0.321429
# 4  1.000000                  0.6            1.0          0.535714
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# 0               0.50                    1.000000       0.357143
# 1               0.75                    1.000000       0.171429
# 2               0.75                    1.000000       0.257143
# 3               0.75                    0.333333       0.614286
# 4               0.75                    0.000000       0.771429
#
#    EmpJobInvolvement  EmpJobLevel  EmpJobSatisfaction  NumCompaniesWorked  \
# 0           0.666667         0.25                 1.0            0.111111
# 1           0.666667         0.25                 0.0            0.222222
# 2           0.333333         0.50                 0.0            0.555556
# 3           0.333333         1.00                 1.0            0.333333
# 4           0.666667         0.25                 0.0            0.888889
#
#    EmpLastSalaryHikePercent  EmpRelationshipSatisfaction  \
# 0                  0.071429                     1.000000
# 1                  0.071429                     1.000000
# 2                  0.714286                     0.666667
# 3                  0.285714                     0.333333
# 4                  0.214286                     1.000000
#
#    TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                       0.250               0.333333            0.333333
# 1                       0.500               0.333333            0.666667
# 2                       0.500               0.333333            0.666667
# 3                       0.575               0.333333            0.333333
# 4                       0.250               0.166667            0.666667
#
#    ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                         0.250                      0.388889
# 1                         0.175                      0.388889
# 2                         0.450                      0.722222
# 3                         0.525                      0.333333
# 4                         0.050                      0.111111
#
#    YearsSinceLastPromotion  YearsWithCurrManager  EmpJobRoleEncod  Gender  \
# 0                 0.000000              0.470588         0.722222       1
# 1                 0.066667              0.411765         0.722222       1
# 2                 0.066667              0.705882         0.722222       1
# 3                 0.800000              0.352941         0.444444       1
# 4                 0.133333              0.117647         0.722222       1
#
#    MaritalStatus  BusinessTravelFrequency  OverTime  Attrition  \
# 0              1                        3         1          1
# 1              1                        3         1          1
# 2              2                        2         0          1
# 3              0                        3         1          1
# 4              1                        3         1          1
#
#    PerformanceRating
# 0                  3
# 1                  3
# 2                  4
# 3                  3
# 4                  3

# %%
#Independent and dependent variable
x=data_model.drop("PerformanceRating",axis=1)
y=data_model["PerformanceRating"]

# %%
y.value_counts()
# Out:
# PerformanceRating
# 3    874
# 2    194
# 4    132
# Name: count, dtype: int64

# %% [markdown]
# ## Imbalanced Data

# %%
#Object creation
smote=SMOTE()

# %%
x_resample,y_resample=smote.fit_resample(x,y)
#print(x_resample.isna().sum())

# %%
print(y_resample.value_counts())
# Out:
# PerformanceRating
# 3    874
# 4    874
# 2    874
# Name: count, dtype: int64

# %%
print(x_resample.shape)
print(y_resample.shape)
# Out:
# (2622, 26)
# (2622,)

# %% [markdown]
# # Model Creation - SVM

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_resample,y_resample,random_state=42)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (1966, 26)
# (1966,)
# (656, 26)
# (656,)

# %%
from sklearn.svm import SVC
svclassifier=SVC() #Object Creation
svclassifier.fit(x_train,y_train)
# Out:
# SVC()

# %%
#Prediction
y_hat=svclassifier.predict(x_test)

# %% [markdown]
# # Classification Report

# %%
#Model Evaluation
from sklearn.metrics import classification_report
print(classification_report(y_test,y_hat))
# Out:
#               precision    recall  f1-score   support
#
#            2       0.85      0.97      0.91       237
#            3       0.91      0.71      0.80       207
#            4       0.88      0.94      0.91       212
#
#     accuracy                           0.88       656
#    macro avg       0.88      0.87      0.87       656
# weighted avg       0.88      0.88      0.87       656

# %%
#import functions_script
from functions_script import apply_mappings, encode_and_drop_columns, scale_features  # Import from the script where they are defined
import joblib
data_processing_pipeline=joblib.load('processed_pipeline.pkl')

# %%
#Dealing the NaN values during passing pipeline
imputer = SimpleImputer(strategy='most_frequent')
x_train_imputed = imputer.fit_transform(x_train)

#convert loaded pipeline to Dataframe
data_processing_pipeline.set_output(transform='pandas')

#Creating new pipeline
full_pipeline = Pipeline([
    ('data_processing', data_processing_pipeline),
    ('imputer',imputer),
    ('classifier', svclassifier)
])

#Again convert new pipeline to Dataframe
full_pipeline.set_output(transform='pandas')
# Out:
# Pipeline(steps=[('data_processing',
#                  Pipeline(steps=[('mapping_transformer',
#                                   FunctionTransformer(func=<function apply_mappings at 0x0000022C2C377F60>)),
#                                  ('label_encoding_transformer',
#                                   FunctionTransformer(func=<function encode_and_drop_columns at 0x0000022C2DF7C540>)),
#                                  ('scaling',
#                                   FunctionTransformer(func=<function scale_features at 0x0000022C2DF7C4A0>))])),
#                 ('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('classifier', SVC())])

# %%
#Converting the varable to Dataframe
x_train_imputed = pd.DataFrame(x_train_imputed, columns=data_model.drop("PerformanceRating", axis=1).columns)

# %%
full_pipeline.fit(x_train_imputed,y_train)
# Out:
# Pipeline(steps=[('data_processing',
#                  Pipeline(steps=[('mapping_transformer',
#                                   FunctionTransformer(func=<function apply_mappings at 0x0000022C2C377F60>)),
#                                  ('label_encoding_transformer',
#                                   FunctionTransformer(func=<function encode_and_drop_columns at 0x0000022C2DF7C540>)),
#                                  ('scaling',
#                                   FunctionTransformer(func=<function scale_features at 0x0000022C2DF7C4A0>))])),
#                 ('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('classifier', SVC())])

# %%
#Saving the pipeline with trained data
joblib.dump(full_pipeline,'trained_pipeline.pkl')
# Out:
# ['trained_pipeline.pkl']
