# %%
import pandas as pd
import joblib

# %%
#New data for prediction
new_data=pd.read_excel("New_data.xlsx") # 
new_data.head()
# Out:
#   EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 0  E1001025   25    Male           Marketing       Married         Sales
# 1  E1001064   28    Male               Other        Single         Sales
# 2  E1001181   40  Female           Marketing       Married         Sales
# 3  E1001307   60    Male             Medical       Married         Sales
# 4  E1001334   55  Female             Medical       Married         Sales
#
#              EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0       Sales Executive           Travel_Rarely                30
# 1       Sales Executive           Travel_Rarely                 2
# 2       Sales Executive           Travel_Rarely                 2
# 3               Manager           Travel_Rarely                 8
# 4  Sales Representative           Travel_Rarely                10
#
#    EmpEducationLevel  EmpEnvironmentSatisfaction  EmpHourlyRate  \
# ...

# %%
predict_pipeline=joblib.load('trained_pipeline.pkl')

# %%
predictions=predict_pipeline.predict(new_data)
print(predictions)
# Out:
# [3 4 3 3 3]
